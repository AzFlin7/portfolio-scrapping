# %%
import pandas as pd
import numpy as np
import panel as pn
from panel.interact import interact
import libs.dashboard as dashboard

import plotly.express as px
import panel as pn
# %matplotlib inline
pn.extension("plotly")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-f13d453c2d1f> in <module>
#       3 import panel as pn
#       4 from panel.interact import interact
# ----> 5 import libs.dashboard as dashboard
#       6
#       7 import plotly.express as px
#
# ModuleNotFoundError: No module named 'libs'

# %%
crypto_checkboxes = pn.widgets.CheckBoxGroup(name='Cryptocurrencies', value=['BTC'], 
                                  options=["BTC","XRP","ETH","LTC","BCH","XLM"],inline=True)

index_checkboxes = pn.widgets.CheckBoxGroup(name='Index', value=['VOO'], 
                                  options=["VOO","VXF","VEA","BSV","BNDX","FLRN"],inline=True)

crypto_row_upper = pn.Row(crypto_checkboxes)
crypto_row_lower = pn.Row(index_checkboxes)
select_button = pn.widgets.Button(name="Select these assets", button_type='primary')

def click_select_button_evnt(event):
    print(select_button.disabled)
    select_button.disabled = True
    select_button.button_type = "danger"
    ticker_dict = {"crypto": crypto_checkboxes.value,
              "index": index_checkboxes.value}
    
    panel  = dashboard.get_dashboard(ticker_dict, mc_trials = 30)
    
    select_button.disabled = False
    select_button.button_type = "primary"
    
    panel.show()

    
select_button.on_click(click_select_button_evnt)

crypto_rows_column = pn.Column(crypto_row_upper, crypto_row_lower, select_button, align = "center", margin= (25,25) )

crypto_rows_column
# Out:
# Column(align='center', margin=(25, 25))
#     [0] Row
#         [0] CheckBoxGroup(inline=True, name='Cryptocurrencies', options=['BTC', 'XRP', ...], value=['BTC'])
#     [1] Row
#         [0] CheckBoxGroup(inline=True, name='Index', options=['VOO', 'VXF', ...], value=['VOO'])
#     [2] Button(button_type='primary', name='Select these assets')

# %%
ticker_dict = {"crypto": [],
              "index": []}

panel  = dashboard.get_dashboard(ticker_dict, mc_trials = 30)

panel
# Out:
# 'Empty list of assets'

# %%
dashboard.mc.get_historic_data(ticker = ["VOO"])
# Out:
#                VOO
#              close   volume
# date
# 2018-09-20  269.75  3349666
# 2018-09-21  269.56  1352509
# 2018-09-24  268.66  2070891
# 2018-09-25  268.33  2360730
# 2018-09-26  266.34  2568392
# ...            ...      ...
# 2019-09-12  276.65  2433713
# 2019-09-13  276.58  2292208
# 2019-09-16  275.67  1432383
# 2019-09-17  276.42  1791361
# 2019-09-18  276.59  2030540
#
# [250 rows x 2 columns]
